# %%
import matplotlib.pyplot as plt
import numpy as np
from keras.datasets import mnist
(train_images, train_labels) = mnist.load_data()

# %%
src = train_images[0][1]
plt.imshow(src)
plt.show()

# %%
reversed_src = 255 - src
plt.imshow(reversed_src)
plt.show()

# %%
bmo = plt.imread('bmo.jpg')
plt.imshow(b)
plt.show()

# %%
print(bmo.dtype)
print(bmo.shape)
print(bmo[0])
# Out:
# uint8
# (1000, 1000, 3)
# [[250 250 250]
#  [250 250 250]
#  [250 250 250]
#  ...
#  [250 250 250]
#  [250 250 250]
#  [250 250 250]]

# %%
r,g,b = bmo[:,:,0], bmo[:,:,1], bmo[:,:,2]
gray = 0.3 * r + 0.59 * g + 0.11 * b
gray /= 255.0
print(gray)
plt.imshow(gray, cmap='gray')
plt.show()
# Out:
# [[0.98039216 0.98039216 0.98039216 ... 0.98039216 0.98039216 0.98039216]
#  [0.98039216 0.98039216 0.98039216 ... 0.98039216 0.98039216 0.98039216]
#  [0.98039216 0.98039216 0.98039216 ... 0.98039216 0.98039216 0.98039216]
#  ...
#  [0.98039216 0.98039216 0.98039216 ... 0.98039216 0.98039216 0.98039216]
#  [0.98039216 0.98039216 0.98039216 ... 0.98039216 0.98039216 0.98039216]
#  [0.98039216 0.98039216 0.98039216 ... 0.98039216 0.98039216 0.98039216]]
